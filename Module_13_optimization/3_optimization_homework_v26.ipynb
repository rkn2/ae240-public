# %% [markdown]
# # Optimization Homework (27 pts)
#
#
# ---
#
# **Generative AI Policy:** You are welcome to use AI tools to help you learn, understand, and debug. If you do, you must disclose it. For any task where you used AI, include the tool name, the exact prompt, and a brief description of how you used the output. If you did not use AI on a task, write: *"No AI used."* You will receive the point either way as long as you note it.

# %% [markdown]
# # Problem 1: Optimizing Lamp Illumination (15 points)
#
# A lamp is suspended above the center of a round table with a radius $r$. The illumination $I$ at the edge of the table depends on the lamp's height $h$. The relationship is given by the formula:
#
# $$I(h)=\frac{I_{0}h}{(r^{2}+h^{2})^{3/2}}$$
#
# Your goal is to find the height $h$ that provides the maximum illumination when the table's radius is $r=5$ ft and the light source intensity is $I_{0}=100$ Watts.
#
#
# This problem will guide you through the process of modeling and optimization.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Part A: Visualize the Ground Truth (2 pts total)**
#
# First, let's treat the equation as our "ground truth" to generate a dataset.
#
# (1 pt) Create the h and I data arrays.
#
# * Instructions for h: Use np.linspace(start, stop, num). Use a start of 0.1 (to avoid errors at zero), a stop of 15, and a num of 100.
#
# * Instructions for I: Create the new array I by plugging your h array directly into the formula. Remember to use r=5, I0=100, and ** for exponents.
#
# (1 pt) Plot the data (Illumination vs. Height) and answer the following question:
#
# Question: Visually inspect your plot. Does the curve look symmetric or asymmetric? (i.e., is the slope going up to the peak a mirror image of the slope coming down?)

# %%
# your code here

# %% [markdown]
# TEXT ANSWER HERE

# %% [markdown]
# **Part B: First Attempt - The Simple Model (3 pts total)**
#
# Based on our in-class lesson, a logical first guess for a curve with one peak is a simple 2nd-order (quadratic) model. Let's test this hypothesis.
#
# (1 pt) Define a model_fn for a 2nd-order polynomial: $y = a*(x-b)^2 + c$.
#
# (1 pt) Use scipy.optimize.curve_fit to fit this model to your data from Part A, and then plot the fitted quadratic curve on the same graph as your data points.
#
# (1 pt) Question: How well does this model fit the data? In your answer, specifically describe the fit. Does it match the peak? Does it accurately follow the curve on both sides of the peak?

# %%
# your code here

# %% [markdown]
# TEXT ANSWER HERE

# %% [markdown]
# **Part C: Second Attempt - The Flexible Model (3 pts total)**
#
# You should see in Part B that the simple 2nd-order model is a poor fit. This is because our data is asymmetric, but a parabola is perfectly symmetric. We need a more flexible model that can bend in more ways to capture the true shape!!
#
# (1 pt) Define a new, more flexible model_fn for a 4th-order (quartic) polynomial: $y = a*x^4 + b*x^3 + c*x^2 + d*x + e$.
#
# (1 pt) Use scipy.optimize.curve_fit to fit this new model to your data, and then plot this new 4th-order curve on your graph (you can remove the 2nd-order plot to keep it clean).
#
# (1 pt) Question: How does this 4th-order model compare to the 2nd-order model? Why is it so much more effective at capturing the shape of this specific data?

# %%
# your code here

# %% [markdown]
# TEXT ANSWER HERE

# %% [markdown]
# **Part D: Optimize the Best Model (2 pts total)**
#
# Now that you have a trustworthy model (the 4th-order one), you can use it to find the optimal height.
#
# (1 pt) Create an objective function that uses your 4th-order model's parameters.
#
# (1 pt) Use the minimize function to find the optimal height and print a clear statement with your final answer: "The computational optimal height for maximum illumination is X ft."
#
# Hint: Remember, we want to find the MAXIMUM, but scipy.optimize.minimize only finds a MINIMUM. You will need to define your objective function to minimize the negative of your model. Use the plot to make an intelligent initial guess for x0.

# %%
# your code here

# %% [markdown]
# **Part E: Finding the Optimum Without Guessing (3 pts total)**
#
# In Part D, you had to guess a reasonable starting point (`x0`) for `minimize()` to work. In class, we saw another way to find a maximum: using the function's derivative directly, since the maximum occurs where the slope of the curve is exactly zero.
#
# (1 pt) Write a `derivative` function for your 4th-order model: given $y = a x^4 + b x^3 + c x^2 + d x + e$, its derivative is $y' = 4a x^3 + 3b x^2 + 2c x + d$.
#
# (1 pt) Define an objective function that returns the **square** of the derivative (squaring avoids the sign issue -- we want the point where the derivative is zero, not just very negative). Use `minimize()` to find the height where this is smallest, the same way we did in class. If it reports it couldn't fully converge, try a tighter `tol` (e.g. `tol=1e-14`).
#
# (1 pt) Print the height found this way and compare it to your answer from Part D. Are they close?

# %%
# your code here

# %% [markdown]
# TEXT ANSWER HERE

# %% [markdown]
# **Part F: Analytical vs. Computational Solution (2 pts total)**
#
# For this specific problem, calculus shows that the true optimal height is when $h = \frac{r}{\sqrt{2}}$.
#
# (1 pt) Calculate the analytical (exact) answer for $r=5$.
#
# (1 pt) Compare and Explain: How does this exact answer compare to the computational answers you found in Parts D and E? Do they agree closely with each other? Why is there a small difference from the analytical answer? (Hint: Think about what curve_fit is actually doing.)

# %%
# CODE HERE

# %% [markdown]
# YOUR RESPONSE HERE

# %% [markdown]
# # Problem 2: Architectural Engineering Optimization in Practice (10 pts)
# Describe an optimization problem you have faced or will face in an AE class. Your answer should be detailed and address the following parts.
#
# **Part A: The Model & Justification (6 points)**
# Describe the Problem (2 pts): Clearly describe a specific optimization problem relevant to architectural engineering. This could be from a structural, mechanical, lighting, or construction course.
#
# Identify Parameters (2 pts): What are the key variables you would need to optimize? What are you trying to maximize or minimize (e.g., cost, energy, comfort, productivity)?
#
# Sketch and Justify (2 pts): Sketch a plot that shows the relationship between your key parameters. Most importantly, justify the shape of your curve. Explain the underlying physical, economic, or logistical principles that cause the relationship you've drawn (e.g., why is it a parabola, why does it show diminishing returns?).
#
# **Part B: Real-World Application (4 points)**
# Identify Constraints (2 pts): Real-world engineering projects are full of constraints. Identify at least two real-world constraints (e.g., budget, building codes, material availability, client preferences) that would impact your problem and explain how you might have to adjust your "optimal" solution to satisfy them.
#
# Objective Function (2 pts): Is your problem a single-objective problem (e.g., purely minimizing cost) or a multi-objective problem (e.g., balancing cost, energy performance, and occupant comfort)? Explain your reasoning.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## AI Reflection (2 pts)
#
# In the text cell below, briefly describe your use of any AI tools (ChatGPT, Claude, Copilot, etc.) on this homework.
#
# - What tasks did you use AI for? (1 pt)
# - Did the AI give you correct information? How could you tell? (1 pt)
#
# If you did not use any AI tools, write "None."

# %% [markdown]
# *Write your response here.*

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb
