# %% [markdown]
# # Intro to Python: Homework (53 pts)
#
#
# ---
#
# **Generative AI Policy:** You are welcome to use AI tools to help you learn, understand, and debug. If you do, you must disclose it. For any problem where you used AI, include the tool name, the exact prompt, and a brief description of how you used the output. If you did not use AI on a problem, write: *"No AI used."* You will receive the point either way as long as you note it.

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To get the sharing link, please click on the "Share" Button on the top right corner

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Please make sure everyone with the link has sharing access. It should look like this: ![image.png](data:image/png;base64,...)

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem 1: Fix the Broken Code (2 pts each) (10 pts)
#
# Each code cell below has a bug. For each one:
# - Fix the bug so the code runs correctly (1 pt)
# - Add a comment explaining what was wrong (1 pt)

# %% [markdown]
# **A)**

# %%
print "Hello, Python!"
# This should print "Hello, Python!" to the console

# %% [markdown]
# **B)**

# %%
for a in range(3):
print(a)

# %% [markdown]
# **C)**

# %%
list(range[2, 12, 2])

# %% [markdown]
# **D)**

# %%
for a in [1, 2, 3]
    print(a)

# %% [markdown]
# **E)**

# %%
# 2 * 3 should equal 6
a = '2'
b = 3
c = a * b
print(c)

# %% [markdown]
# ## Problem 2: Variables and Calculation (4 pts)
#
# - Define a variable equal to `1.5` (1 pt)
# - Define a second variable equal to `6.3` (1 pt)
# - Add them using only the variable names (1 pt)
# - Print the result (1 pt)

# %%
# ADD CODE HERE

# %% [markdown]
# ## Problem 3: Math and Printing (7 pts)
#
# - Define a variable for leg 1 equal to `5` (1 pt)
# - Define a variable for leg 2 equal to `12` (1 pt)
# - Calculate the hypotenuse correctly: $c = \sqrt{a^2 + b^2}$ (1 pt)
# - Store the result in a variable (1 pt)
#   *Hint: a square root is the same as raising to the power `0.5`*
# - Print the result using **string concatenation** with `str()` (1 pt)
# - Print the result using an **f-string** (1 pt)
# - Output for both reads: `The hypotenuse is 13.0` (1 pt)

# %%
# ADD CODE HERE

# %% [markdown]
# ## Problem 4: For Loop (7 pts)
#
# You have a list of temperatures in Fahrenheit:
#
# ```python
# temps_F = [32, 50, 68, 86, 104]
# ```
#
# Conversion formula: $T_C = (T_F - 32) \times \frac{5}{9}$
#
# - Create an empty list called `temps_C` (1 pt)
# - Write a `for` loop that iterates over `temps_F` (1 pt)
# - Apply the correct conversion formula inside the loop (1 pt)
# - Use `append()` to add each result to `temps_C` (1 pt)
# - Print `temps_F` with a label using an f-string (1 pt)
# - Print `temps_C` with a label using an f-string (1 pt)
# - Output matches expected format (1 pt)

# %%
temps_F = [32, 50, 68, 86, 104]

# ADD CODE HERE

# %% [markdown]
# ## Problem 5: Indexing, Slicing, and Labeled Printing (8 pts)
#
# Using your `temps_C` list from Problem 4:
#
# - Print the **hottest** temperature using the last-index shorthand (1 pt)
# - Label it `"Hottest: X °C"` (1 pt)
# - Print the **coldest** temperature using the first-index shorthand (1 pt)
# - Label it `"Coldest: X °C"` (1 pt)
# - Use slicing `list[start:stop]` to extract the middle 3 values (1 pt)
#   *`list[start:stop]` extracts items from index `start` up to (but not including) `stop`*
# - Store the slice in a list called `mild_temps_C` (1 pt)
# - Print `mild_temps_C` with the label `"Mild range:"` (1 pt)
# - Values in `mild_temps_C` are correct (1 pt)

# %%
# ADD CODE HERE

# %% [markdown]
# ## Problem 6: Plotting (11 pts)
#
# Plot `temps_F` on the x-axis and `temps_C` on the y-axis.
#
# - Import `matplotlib.pyplot as plt` (1 pt)
# - Create a figure using `plt.subplots()` (1 pt)
# - Use meaningful variable names, not just `fig` and `ax` (1 pt)
# - Plot the data using `ax.plot()` (1 pt)
# - Use `marker=` to show individual points (1 pt)
# - Use `linestyle=` to remove the connecting line (1 pt)
# - Set marker color to blue (1 pt)
# - Add correct x-axis label: `'Temperature (°F)'` (1 pt)
# - Add correct y-axis label: `'Temperature (°C)'` (1 pt)
# - Add correct title: `'Fahrenheit to Celsius Conversion'` (1 pt)
# - Plot renders without errors (1 pt)
#
# Look at the [matplotlib documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html) for the `color=`, `marker=`, and `linestyle=` keyword arguments.

# %%
import matplotlib.pyplot as plt

# ADD CODE HERE

# %% [markdown]
# ## Problem 7: Written Response (4 pts)
#
# Answer the following questions about your plot from Problem 6 in the text cell below.
#
# - Describe whether the relationship between Fahrenheit and Celsius is linear (1 pt)
# - Support your answer with reasoning from the plot (1 pt)
# - Identify the Fahrenheit temperature where the plot crosses 0°C (1 pt)
# - Explain whether this matches the known freezing point of water (1 pt)
#
# **To add a text cell:** click the `+` button in the toolbar and select Markdown (or Text). Double-click any text cell to edit it.

# %% [markdown]
# *Write your response here.*

# %% [markdown]
# ## AI Reflection (2 pts)
#
# In the text cell below, briefly describe your use of any AI tools (ChatGPT, Claude, Copilot, etc.) on this homework.
#
# - What tasks did you use AI for? (1 pt)
# - Did the AI give you correct information? How could you tell? (1 pt)
#
# If you did not use any AI tools, write "None."

# %% [markdown]
# *Write your response here.*
