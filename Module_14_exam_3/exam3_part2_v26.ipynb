# %% [markdown]
# # Part 2: In-Class Conceptual Analysis (11 Points)
#
# *This is a closed-book, closed-note exam. You will be provided with the expected outputs from the take-home programming portion of the exam. Please answer the following questions based on those outputs and the concepts covered in class*.
#
# ## 1. Grouped Data Analysis and Risk Interpretation (4 Points)
#
# The preliminary analysis in Part 1, Task 1.B required grouping the data by `Project_Type` and calculating the mean and standard deviation of the `Energy_Yield_Index`. The resulting bar chart visualized these summary statistics, using the standard deviation as error bars.
#
# A. The bar chart displays the **mean** energy yield index and the **standard deviation**. How is each statistic meant to be interpreted by an analyst viewing the bar chart? (1 pt for mean, 1 pt for standard deviation).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ANSWER HERE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B. In the context of the bar chart, explain how the visualization of the standard deviation (the error bars) helps assess **risk** (1 pt). If a project type (e.g., 'Commercial' vs. 'Industrial' vs. 'Residential') shows a mean yield that is only slightly higher than another, but its standard deviation is much larger, explain why an investment fund might categorize the project with the larger standard deviation as the riskier investment (1 pt).

# %% [markdown]
# **ANSWER HERE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Optimization Method Comparison (3 Points)
#
# Part 1, Task 3 utilized `scipy.optimize.minimize()` to efficiently find the optimal investment hours. Contrast this numerical solver approach with a Brute Force or Grid Search method, as discussed in the course notes.
#
# A. Identify the **limitations** of using a high-resolution Grid Search method to find an optimum point (like the minimum cost for a building height example) (1 pt).

# %% [markdown]
# **ANSWER HERE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B. Numerical optimization methods are often preferable to Grid Search for complex Architectural Engineering (AE) problems involving 10 or more variables (e.g., wall position, thickness, material type, etc.). Explain the phenomenon (**The Curse of Dimensionality**) that makes Grid Search quickly impractical in these high-dimensional scenarios (2 pts).

# %% [markdown]
# **ANSWER HERE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3: Conceptual Analysis of the Cubic Model (4 Points)
#
# The analysis in Part 1, Tasks 2 and 3, determined that the Cubic Model was the best fit for the diminishing returns data.
#
# A. Explain the **physical meaning** of the point found by minimizing the negative of the objective function (Task 3.A) (1 pt). In the context of the data (Investment vs. Energy Yield Index), what does the calculated result (e.g., Optimal Investment of 14.67k yielding a Maximum Predicted Yield Index of 56.06) represent for an energy analyst? (1 pt).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ANSWER HERE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B. While it is not pictured / applicable in this example, the **Point of Diminishing Returns** is found where the second derivative of the function is zero (the inflection point). Imagine you did have this part of the graph visible within your bounds. Explain what happens to the **rate of change (slope)** of the Energy Yield Index immediately after an inflection point (1 pt). Why could this point be significant for project management decisions, even though it occurs before the Maximum Yield is achieved? (1 pt).

# %% [markdown]
# **ANSWER HERE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb
