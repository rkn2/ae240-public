# %% [markdown]
# # Exam 1
#
# **Part 1: 39 pts** | **Part 2: 10 pts** | **Total: 49 pts**

# %% [markdown]
# Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To get the sharing link, please click on the "Share" Button on the top right corner

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Please make sure everyone with the link has sharing access. It should look like this: ![image.png](data:image/png;base64,...)

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Debugging section
#
# For each example, correct the code (1pt) and comment what was wrong (1pt)

# %% [markdown]
# ## Debugging #1
#
# Here is what the result of this code should look like:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Comment out the line of code that is extraneous inorder to make the plot above. (Comments do not count!) This checks to make sure you understand what lines of code are actually important!

# %%
import numpy as np # this is the
import matplotlib.pyplot as plt
# Sample data for site accessibility ratings (on a scale of 1 to 10)
site_accessibility = [7, 8, 6, 9, 4, 8, 5, 6, 7, 3]
# Sample data for estimated construction costs (in dollars)
construction_costs = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]
# Create subplots
fig, ax = plt.subplots()
# Scatter plot
ax.scatter(site_accessibility, construction_costs, label='construction_costs', color='g', marker = '*')
# Add labels and legend
ax.set_xlabel('Site area (m2)')
ax.set_ylabel('Varies')
ax.legend()

# %%
# Fix the code below and add a comment explaining what was wrong

# %% [markdown]
# ## Debugging #2
#
# Fix the error.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Sample data for site accessibility ratings (on a scale of 1 to 10)
site_accessibility = [7, 8, 6, 9, 4, 8, 5, 6, 7, 3]
# Sample data for estimated construction costs (in dollars)
construction_costs = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]
# Create subplots
fig, ax = plt.subplots()
# Scatter plot
ax.scatter(site_accessibility, construction_costs, label='construction_costs', color='g', marker = '*')
# Add labels and legend
plt.set_xlabel('Site area (m2)')
plt.set_ylabel('Varies')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ec2613e957ec> in <cell line: 12>()
#      10 ax.scatter(site_accessibility, construction_costs, label='construction_costs', color='g', marker = '*')
#      11 # Add labels and legend
# ---> 12 plt.set_xlabel('Site area (m2)')
#      13 plt.set_ylabel('Varies')
#      14 plt.legend()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xlabel'

# %%
import numpy as np
import matplotlib.pyplot as plt
# Sample data for site accessibility ratings (on a scale of 1 to 10)
site_accessibility = [7, 8, 6, 9, 4, 8, 5, 6, 7, 3]
# Sample data for estimated construction costs (in dollars)
construction_costs = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]
# Create subplots
fig, ax = plt.subplots()
# Scatter plot
ax.scatter(site_accessibility, construction_costs, label='construction_costs', color='g', marker = '*')
# Add labels and legend
ax.set_xlabel('Site area (m2)')
ax.set_ylabel('Varies')
ax.legend()

# %% [markdown]
# # Application section
#
# You are tasked with evaluating the site characteristics of a potential construction site for a building project. You have collected data on various site parameters and their potential impact on construction costs.
#
# Your goal is to write a Python program to perform site analysis, visualize the data, and determine if there is a correlation between specific site characteristics and estimated construction costs.
#
# You must follow these steps for full credit:
#
# * Use the range command and a for loop to **automatically** generate a list of areas for the sites. The list should contain areas from 100 m2 to 1000 m2 (inclusive) with a step of 100 m2. Print this list to the screen. (1 point for start, 1 point for stop, 1 point for step)
#
# * Create a **scatter plot** of the data points (areas vs. cost and areas vs accessibility) using Matplotlib. Show the scatter plot with just the data points (2pts). Make sure you have a legend with a descriptive label for your data (1pt), a title (1pt), axis labels with units (1pt), and the dots for accessibility should be blue '^' markers (1pt), the dots for cost can be whatever color and icon you chose (1pt).
#
#
# * Calculate and print to the screen the **slope and intercept** of the linear regression line representing the site accessibility as a function of site area using the linregress function from the scipy.stats module in this format 'Linear Regression Equation: Accessibility =  `variable_for_slope`  * Area +  `variable_for_intercept`. (2 pts for setting up the regression) Slope and intercept are the variables we want to insert here, Accessibilty and Area are just the strings since those will change with each data point.
#
# * Calculate the linear regression for the accessibility data so you can set up your linear model (2pts)
#
# * Calculate and print to the screen the **slope and intercept** of the linear regression line representing the site cost as a function of site area using the linregress function from the scipy.stats module in this format 'Linear Regression Equation: Cost =  `whatever_you_call_this_slope`  * Area +  `whatever_you_call_this_intercept`. (2 pts for setting up the regression) Slope and intercept are the variables we want to insert here, cost and Area are just the strings since those will change with each data point.
#
# * Calculate the linear regression for the cost data so you can set up your linear model (2pts)
#
# * Plot the linear regression line for accessibility (1pt) on the **same graph** as your scatter plot (1pt). Show the scatter plot and the linear regression on the same plot. Make sure your legend is updated to have the linear regression label included. (1pt)
#
# * Plot the linear regression line for cost (1pt) on the **same graph** as your scatter plot and accessibility linear model(1pt). Show the scatter plot and the linear regression on the same plot. Make sure your legend is updated to have the linear regression label included. (1pt)

# %% [markdown]
# Okay back to the problem at hand! Here are the last steps
#
# * **Think about it and write an explanation**: As the area of the site increases what does this mean according to our model for the accessibility? (1pt), make a comment about the relatibility of this prediction based on the r_value (1pt) and the std_error (1 pt)
# * **Think about it and write an explanation**: As the area of the site increases what does this mean according to our model for the cost? (1pt), make a comment about the relatibility of this prediction based on the r_value (1pt) and the std_error (1 pt).
#
# * **Think about it and write an explanation**: So which one of these models is more likely to be a good representation of our data? The one for cost or the one for accessibilty? (2 pts) Why? (2pts)
#
# * Make sure all your code is commented (1pt)

# %%
# your data
# Sample data for site accessibility ratings (on a scale of 1 to 10)
site_accessibility = [7, 8, 6, 9, 4, 8, 5, 6, 7, 3]

# Sample data for estimated construction costs (in dollars)
construction_costs = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000]

# %%
# ADD CODE HERE

# %% [markdown]
# For Accessibility:
#
# *Write your response here.*

# %% [markdown]
# For Cost:
#
# *Write your response here.*

# %% [markdown]
# Based on the analysis:
#
# *Write your response here.*
