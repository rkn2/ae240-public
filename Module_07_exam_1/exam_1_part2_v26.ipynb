# %% [markdown]
# # **Part 2 IN CLASS (10 pts)**

# %% [markdown]
# Instructions: This is a closed-book, closed-note section. Answer the following questions based on the plots and regression results generated in the programming portion.

# %% [markdown]
# Results from Part 1 that you might need:
#
# Accessibility Results: `r_value` is -0.4955, `std_err` is 0.0019, `slope` is -0.0031, and `intercept` is 8.0.
#
# Cost Results: `r_value` is 1.0, `std_err` is 0.0, `slope` is 1000.0, and `intercept` is 0.0.

# %% [markdown]
# **Question 1: Reading the Plot Critically (3 points)**

# %% [markdown]
# Here is the combined plot from Part 1 with both datasets and regression lines:
#
# ![Combined plot](data:image/png;base64,...)

# %% [markdown]
# a) (1 pt) On this combined plot, the accessibility regression line appears nearly flat compared to the cost line. Does this mean accessibility doesn't change with area? Explain using the numerical slope.

# %% [markdown]
# ![answer lines](data:image/png;base64,...)

# %% [markdown]
# b) (2 pts) A client looks at your plot and concludes "area has no effect on accessibility." What would you tell them, and what could you do differently with your visualization to avoid this misunderstanding?

# %% [markdown]
# ![answer lines](data:image/png;base64,...)

# %% [markdown]
# **Question 2: Making Predictions (4 points)**

# %% [markdown]
# Here is the accessibility data plotted on its own, so you can see the trend more clearly:
#
# ![Accessibility vs Area](data:image/png;base64,...)

# %% [markdown]
# In Part 1, you found that the regression equation for accessibility is:
#
# Accessibility = -0.0031 * Area + 8.0
#
# What if we wanted to predict the accessibility for a much larger site? Let's plug in Area = 5000 m²:
#
# Accessibility = -0.0031 * 5000 + 8.0 = -15.5 + 8.0 = **-7.5**

# %% [markdown]
# a) (1 pt) On the plot above, sketch what the regression line would look like if you extended it out to Area = 5000 m². Mark the predicted value of -7.5 on your sketch.

# %% [markdown]
# b) (1 pt) Does a rating of -7.5 make physical sense for an accessibility rating on a scale of 1 to 10 (not negative)? Why or why not?

# %% [markdown]
# ![answer lines](data:image/png;base64,...)

# %% [markdown]
# c) (1 pt) Your data only included sites from 100 to 1000 m². The 5000 m² site is far outside that range. In your own words, why is it risky to use a model to predict values outside the range of the original data?

# %% [markdown]
# ![answer lines](data:image/png;base64,...)

# %% [markdown]
# d) (1 pt) Would you be more or less worried about predicting the cost for a 1500 m² site (just slightly outside your range) versus the accessibility for a 5000 m² site (far outside your range)? Explain.

# %% [markdown]
# ![answer lines](data:image/png;base64,...)

# %% [markdown]
# **Question 3: Variable Names Matter (3 points)**

# %% [markdown]
# A classmate wrote the following code to run two regressions and plot both lines:

# %% [markdown]
# ```python
# # First regression - accessibility
# slope, intercept, r_value, p_value, std_err = linregress(
#     site_areas, site_accessibility)
#
# # Second regression - cost
# slope, intercept, r_value, p_value, std_err = linregress(
#     site_areas, construction_costs)
#
# # Build predicted values for accessibility
# predicted_access = []
# for area in site_areas:
#     y = slope * area + intercept
#     predicted_access.append(y)
#
# # Build predicted values for cost
# predicted_cost = []
# for area in site_areas:
#     y = slope * area + intercept
#     predicted_cost.append(y)
#
# # Plot both regression lines
# ax.plot(site_areas, predicted_access, color='b',
#         label='Accessibility: y=' + str(slope)
#               + '*x+' + str(intercept))
# ax.plot(site_areas, predicted_cost, color='g',
#         label='Cost: y=' + str(slope)
#               + '*x+' + str(intercept))
# ```

# %% [markdown]
# Here is the plot their code produced. Look at the equations in the legend:
#
# ![Bug plot](data:image/png;base64,...)

# %% [markdown]
# a) (1 pt) Something is clearly wrong. What happened to the accessibility slope and intercept values?

# %% [markdown]
# ![answer lines](data:image/png;base64,...)

# %% [markdown]
# b) (2 pts) Suggest a way to fix this problem and explain why it works.

# %% [markdown]
# ![answer lines](data:image/png;base64,...)

# %% [markdown]
# **Submission:** This part is handwritten and completed in class. Write your name at the top of your page(s); they will be collected at the end of class.
