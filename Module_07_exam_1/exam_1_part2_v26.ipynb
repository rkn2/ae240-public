# %% [markdown]
# # **Part 2 IN CLASS (10 pts)**

# %% [markdown]
# Instructions: This is a closed-book, closed-note section. Answer the following questions based on the plots and regression results generated in the programming portion.

# %% [markdown]
# Results from Part 1 that you might need:
#
# Accessibility Results: $r\_value$ is -0.4955, $std\_err$ is 0.0019, $slope$ is -0.0031, and $intercept$ is 8.0.
#
# Cost Results: $r\_value$ is 1.0, $std\_err$ is 0.0, $slope$ is 1000.0, and $intercept$ is 0.0.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 1: Interpreting Accessibility Trends (3 points)**
#
# Examine the results for the site accessibility model generated by your script.
#
# a) (1 pt) Based on the r_value of -0.4955, describe the correlation between site area and accessibility. Is it positive or negative?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b) (1 pt) Is the correlation strong or weak?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# c) (1 pt) What does the slope tell you about the relationship? Specifically, as the site area increases, what happens to the accessibility rating according to this model?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 2: Model Performance and Statistical Confidence (4 points)**
#
# This question refers to the statistical outputs for both the Cost and Accessibility models.
#
# a) (1 pt) Which of the two models is a better representation of the data?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b) (2 pts) Justify your choice by comparing the r_value and std_err for both datasets.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# c) (1 pt) How does the std_err of 0.0 for the cost model specifically affect your confidence in its results compared to the accessibility model?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 3: Practicality and Scale Challenges (3 points)**
#
# a) (2 pts) In your final plot, the regression line for accessibility appears almost perfectly flat compared to the cost line. Explain why this visualization challenge occurs.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b) (1 pt) Even though the line looks "flat" and suggests no change, why is it important to check the numerical slope and r_value before concluding there is no relationship?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Submission:** This part is handwritten and completed in class. Write your name at the top of your page(s); they will be collected at the end of class.
