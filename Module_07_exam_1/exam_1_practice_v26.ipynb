# %% [markdown]
# # EXAM 1 PRACTICE

# %% [markdown]
# # Debugging section
#
# For each example, correct the code (1pt) and comment what was wrong (1pt)

# %% [markdown]
# ## Debugging #1

# %%
# Data for age of buildings
age_data = [10, 15, 20, 25, 30]

# Data for energy consumption (different length)
energy_consumption = [220, 176, 155, 25, 35]

# Attempt to create a scatter plot
plt.scatter(age_data, energy_consumption)
plt.xlabel('Age of Buildings (years)')
plt.ylabel('Energy Consumption (kWh/m^2/year)')
plt.title('Energy Efficiency Analysis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a22cb4512c53> in <cell line: 8>()
#       6
#       7 # Attempt to create a scatter plot
# ----> 8 plt.scatter(age_data, energy_consumption)
#       9 plt.xlabel('Age of Buildings (years)')
#      10 plt.ylabel('Energy Consumption (kWh/m^2/year)')
#
# NameError: name 'plt' is not defined

# %%
# Fix the code below and add a comment explaining what was wrong

# %% [markdown]
# ## Debugging #2

# %%
import matplotlib.pyplot as plt

# Data for age of buildings
age = [10, 15, 20, 25, 30]

# Data for energy consumption (different length)
energy_consumption = [220, 176, 155, 25, 35]

# Attempt to create a scatter plot
plt.scatter(ages, energy_consumption)
plt.xlabel('Age of Buildings (years)')
plt.ylabel('Energy Consumption (kWh/m^2/year)')
plt.title('Energy Efficiency Analysis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-27927e74a174> in <cell line: 10>()
#       8
#       9 # Attempt to create a scatter plot
# ---> 10 plt.scatter(ages, energy_consumption)
#      11 plt.xlabel('Age of Buildings (years)')
#      12 plt.ylabel('Energy Consumption (kWh/m^2/year)')
#
# NameError: name 'ages' is not defined

# %%
# Fix the code below and add a comment explaining what was wrong

# %% [markdown]
# ## Debugging #3

# %%
import matplotlib.pyplot as plt

# Data for age of buildings
age_data_2 = [10, 15, 20, 25, 30]

# Data for energy consumption
energy_consumption_2 = [220, 176, 155]

# Attempt to create a scatter plot
plt.scatter(age_data_2, energy_consumption_2)
plt.xlabel('Age of Buildings (years)')
plt.ylabel('Energy Consumption (kWh/m^2/year)')
plt.title('Energy Efficiency Analysis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6f2128b0d4a9> in <cell line: 10>()
#       8
#       9 # Attempt to create a scatter plot
# ---> 10 plt.scatter(age_data_2, energy_consumption_2)
#      11 plt.xlabel('Age of Buildings (years)')
#      12 plt.ylabel('Energy Consumption (kWh/m^2/year)')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
# Fix the code below and add a comment explaining what was wrong

# %% [markdown]
# # Application section
#
# You are tasked with analyzing the energy efficiency of a set of buildings in a city. You have collected data on the age of buildings (in years) and their corresponding energy consumption (in kilowatt-hours per square meter per year) for a sample of buildings.
#
# Your task is to write a Python program to perform linear regression analysis to **determine if there is a correlation between the age of buildings and their energy consumption.** Your goal is to create a **scatter plot** of the data points, fit a **linear regression line** to the data, and then **predict the energy consumption for a given age of a building**.
#
# You must follow these steps for full credit:
#
# * Use the range command and a for loop to **automatically** generate a list of ages for the buildings. The list should contain ages from 10 to 55 (inclusive) with a step of 5 years. Print this list to the screen. (1 point for start, 1 point for stop, 1 point for step, 1 point for printing the list and not the range)
#
# * Create a **scatter plot** of the data points (ages vs. energy consumption) using Matplotlib. Show the scatter plot with just the data points (2pts). Make sure you have a legend with a descriptive label for your data (1pt), a title (1pt), axis labels with units (1pt), and the dots should be green '*' markers (1pt).
#
#
# * Calculate and print to the screen the **slope and intercept** of the linear regression line using the linregress function from the scipy.stats module in this format 'Linear Regression Equation: Energy =  `slope`  * Age +  `intercept`. (2 pts for setting up the regression) Slope and intercept are the variables we want to insert here, energy and age are just the strings since those will change with each data point.
#
# * Using a for loop, calculate the linear regression for the given data so you can set up your linear model (similar to what we did in class for velocity model!) (2pts)
#
# * Plot the linear regression line (1pt) on the **same graph** (1pt). Show the scatter plot and the linear regression on the same plot. Make sure your legend is updated to have the linear regression label included. (1pt)
#
# * **Comment**: What do the r_value and std_error tell you about your data? For r_value comment: is it a positive or negative correlation (1pt), is it a strong or weak correlation (1pt), so as the age of the building increases what does this mean according to our model for the energy consumption? (1pt) For your std_error comment: how good of a prediction did this linear model make? (1 pt) **NOTE THE DIFFERENCE BETWEEN R_VALUE AND R2! LOOK AT THE DOCUMENTATION**
#
# * Using your linear model **predict** the energy consumption for a building that is 65 years old (2pts) and print the result to the screen in the format 'Predicted Energy Consumption for a ` predicted_age`'-year-old building: `predicted_energy` kWh/m^2/year'. (1 pt)
#
# * Does the number you predicted **make sense**? (2pts) Why or why not? (2 pts)
#
# * Make sure all your code is commented (1pt)
#
# **[What if on the exam I asked you to plot two different sets of data and create two linear regression lines and compare them, how would you do that?]**

# %%
# your data
energy_consumption = [220, 176, 155, 143, 130, 120, 75, 65, 20, 20] #kWh/m^2/year

# %%
# ADD CODE HERE

# %% [markdown]
# *Write your response here.*

# %%
# ADD CODE HERE

# %% [markdown]
# *Write your response here.*

# %% [markdown]
# #Part 2: In-Class Conceptual Analysis (14 Points)

# %% [markdown]
# Instructions: This is a closed-book, closed-note section. Answer the following questions based on the plots and regression results generated in the programming portion.

# %% [markdown]
# Question 1: Interpreting Linear Regression Results (4 points)
#
# Examine the scatter plot and the linear regression equation you generated: Energy = slope * Age + intercept.
#
# • a) Based on the r_value calculated by your script, describe the correlation between a building's age and its energy consumption. Is the correlation positive or negative? Is it strong or weak?
#
# • b) What does the slope of your regression line tell you about the relationship between age and energy? Specifically, as the building gets older, what happens to the energy consumption according to this model?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 2: Model Performance and Prediction (6 points)
#
# This question refers to the standard error (std_error) and the prediction you made for a 65-year-old building.
#
# • a) Looking at the std_error, how "good" of a prediction did this linear model make? Does a higher standard error make you more or less confident in your results?
#
# • b) You were asked to predict the energy consumption for a building that is 65 years old. Does the numerical result you obtained make physical sense for a building of that age?
#
# • c) Justify whether or not this prediction is a reasonable one based on the original range of your data (ages 10 to 55). (Hint: Consider the risks of predicting values outside the original data range).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 3: Understanding Code Errors and Logic (4 points)
#
# Reflect on the debugging exercises performed at the start of the exam.
#
# • a) In one of the debugging examples, you encountered a ValueError: x and y must be the same size. Explain in your own words what caused this error in the context of creating a scatter plot and how you fixed it.
#
# • b) Why is it necessary to import matplotlib.pyplot as plt before calling a function like ax.scatter()? What specific error (by name) occurs if you forget to do this?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
