# %% [markdown]
# # Analyzing Architectural Dataframes with Python (17 pts)
#
#
# ---
#
# **Generative AI Policy:** You are welcome to use AI tools to help you learn, understand, and debug. If you do, you must disclose it. For any task where you used AI, include the tool name, the exact prompt, and a brief description of how you used the output. If you did not use AI on a task, write: *"No AI used."* You will receive the point either way as long as you note it.

# %% [markdown]
# **Objective**: This assignment is designed to provide experience in performing data analysis on an architectural engineering dataset. Students will use the Python Pandas library to import, clean, and manipulate data. The primary focus is on applying control flow statements (specifically if-elif-else) to analyze project performance, categorize data based on specific criteria, and use Matplotlib to visualize the results. Upon completion, students will be able to draw data-driven conclusions about project ratings and characteristics.

# %% [markdown]
# **Dataset Description:**
# The dataset contains information on 40 architectural projects undertaken by a firm. Each row represents a unique project and includes the following details:
#
# * project_id: A unique numerical identifier for each project.
#
# * project_name: The specific name of the project.
#
# * location: The city where the project is located.
#
# * year: The year the project was completed.
#
# * building_type: The primary function of the building (e.g., Residential, Commercial, Educational).
#
# * rating: A client satisfaction or performance rating on a scale of 1 to 5.
#
# **Problem Scenario:**
# The management team wants to gain a better understanding of the firm's historical project performance to identify strengths and areas for improvement. Your task is to analyze the provided project dataset to answer key questions about project quality. This involves handling missing data, calculating overall and segmented performance metrics (like average ratings), identifying the highest and lowest-performing project types, and creating clear visualizations to present your findings to stakeholders.

# %% [markdown]
# ## Part 1: Reading in the Data (2 pts total)
# The data you will be working with is a sample of architectural projects and their details. The data is stored in a CSV file called architectural_projects.csv. Each row in the file represents a single project, and the columns include:
#
#       `project_id`: A unique identifier for the project.
#
#       `project_name`: The name of the project.
#
#       `location`: The location of the project.
#
#       `year`: The year the project was completed.
#
#       `building_type`: The type of building (e.g. residential, commercial, etc.).
#
#       `rating`: A rating of the project on a scale of 1 to 5.
#
# Use the Pandas library to read in the data from the CSV file into a DataFrame (1pt). Clean any NaNs from the dataframe using either dropna or nested loops (1pt). If you used .dropna() to remove rows with missing values. What is a potential downside of this method? If 20% of the projects were missing a rating, what would be the risk of dropping all of them? If you do use .dropna() please describe an alternative strategy you could use to handle missing rating values instead of dropping the entire row next time. For example, what value could you fill the missing ratings with, and what would be the pros and cons of that choice?

# %%
import pandas as pd
import requests

#import data
url = 'https://pennstateoffice365-my.sharepoint.com/:x:/g/personal/rjn5308_psu_edu/EQLkpturuKtKpWXCdvRMzIcBvauWfBAc5AiFLyC6IwDDJA?e=rfy6dq&download=1'
r = requests.get(url)
r.status_code
with open('architectural_projects.csv', 'w') as fid:
    fid.write(r.text)

# %% [markdown]
# ## Part 2: Analyzing the Data (8 pts total)
# Use control flow statements and dictionaries to analyze the data and answer the following questions:
#
# 1. What is the average rating of all the projects?
#
# * Use an `if/else` statement to determine whether the average rating of all the projects is high (greater than or equal to 4) or low (less than 4). (1pt)
# * Within the `if/else` print a message indicating whether the average rating of all the projects is high or low, along with the average rating value. (1pt)
#
#
# 2. Your analysis should have showed the overall average rating is "low" (3.01). But is this true for all types of projects?
#
# * Calculate the average rating for each unique building_type. (1pt)
#
# * Which building_type has the highest average rating? Which has the lowest? (1pt) You can use the Pandas method `idxmax` (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html) or any other way you prefer
#
# * Print a statement that says, "The building type with the highest average rating is [Building Type] with a rating of [Average Rating]; the building type with the lowest average rating is [Building Type] with a rating of [Average Rating]." (1pt)
#
# 3. The firm wants to flag projects that need urgent review. A project requires review if its rating is below 2.5. Within this group, if the project is also of 'Residential' type, it should be marked as 'High-Priority Review'. All other projects with a rating below 2.5 should be marked as 'Standard Review'. Create a new column called review_status that contains these labels (1pt). Projects with ratings 2.5 or above should have a NaN or 'No Review' value in this column. Then print this to the console (1 pt). After running your script, the console displays a list of all projects flagged for either 'High-Priority' or 'Standard' review. The management team suspects that a particular period might have been challenging for the firm, leading to lower-quality outcomes. Carefully examine the year for each project that was flagged for review in your script's output. Is there one specific year that appears most frequently among these low-rated projects? (1 pt)

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ## Part 3: Visualizing the Data (5 pts total)
# Use the Matplotlib library to create two bar charts:
#
# 1) a bar chart to show the number of projects of each building type (1 pt for the chart, 1 pt for all title and axes labels) and
#
# 2) a bar chart to show the number of projects completed in each year. Use the method .sort_values() from pandas to sort the years in ascending order.
# For help with that see:
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_index.html
# * https://www.statology.org/pandas-value_counts-sort/
# (1 pt for the chart, 1 pt for all title and axes labels, 1 pt for sorting)

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ## Bonus question (1 extra point)
#
# A 1-5 rating can be useful, but sometimes descriptive categories are better. Create a new column in your DataFrame called rating_category. This column should contain a string based on the numerical rating:
#
# * 'Excellent' for ratings greater than or equal to 4.5
#
# * 'Good' for ratings between 3.5 and 4.49
#
# * 'Average' for ratings between 2.5 and 3.49
#
# * 'Needs Improvement' for ratings below 2.5
#
# After creating the new column, create a bar chart showing the number of projects in each rating_category.

# %%
# your code here

# %% [markdown]
# ## AI Reflection (2 pts)
#
# In the text cell below, briefly describe your use of any AI tools (ChatGPT, Claude, Copilot, etc.) on this homework.
#
# - What tasks did you use AI for? (1 pt)
# - Did the AI give you correct information? How could you tell? (1 pt)
#
# If you did not use any AI tools, write "None."

# %% [markdown]
# *Write your response here.*

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb
