# %% [markdown]
# # **Homework 1**
#
# Please upload a written summary of your work along with your original Excel sheet used to perform the calculations. Microsoft Word can import charts directly from Excel using copy and paste, or you can take screen shots. Please use some basic formatting to make the Excel sheet more readable including column headers, descriptive labels for formula outputs (such as writing "Average" next to the output of an `AVERAGE` formula over a column), and adding axis labels to charts.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 1
#
# ![](https://i.imgur.com/z7WAnGV.png)
#
#
# Start with this [Excel sheet](https://pennstateoffice365-my.sharepoint.com/:x:/g/personal/rjn5308_psu_edu/ESrWNe1jBi9KvOnuWaqml_kBNL0fZ5qTyFiMP0sXcXRo3A) with the data already imported.
#
# a) Remove the `#` character from the first column so you can use the numerical values in formulae. This needs to be done using Excel functions, not manual replacement. Some options are the "Text to Columns" button in the ribbon and the `SUBSTITUTE` formula. You can also come up with your own method. Write a few lines explaining your method.
#
# b) Make a scatter plot of the Bar Size versus the Area, Weight, and Diameter data columns. The plot should include a descriptive title, labeled x axis, and legend with units for each data column. Note: plotting multiple columns on a single y axis means we have to put units in the legend instead of on the axis.
#
# c) Use linear trendlines to determine the parameter which best linearly correlates with Bar Size Designation (i.e., whether the Bar Size is a measure of Area, Weight, or Diameter). Report your findings and justify them by discussing R2 values.
#
# d) Determine the density of the rebar in lb/in^3 using Excel formulae (be mindful of units here!). Report a mean and standard deviation (also using Excel formulae).
