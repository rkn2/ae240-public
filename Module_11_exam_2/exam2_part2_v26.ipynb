# %% [markdown]
# # Part 2: In-Class Conceptual Analysis (14 Points)
#
# **Instructions**: This is a closed-book, closed-note exam. You will be provided with the expected outputs (DataFrames and plots) from the take-home programming portion of the exam. Please answer the following questions based on those outputs and the concepts covered in class.
#
# Here was the raw data you were looking at:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 1: Interpreting Data Distribution (3 points)
#
# Examine the histogram you created for project costs.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) Describe the shape of the distribution (1 pts). Is the data symmetric or is it skewed? If skewed, in which direction (left or right)? (1 pt)
#
# b) What does this shape suggest about the nature of the firm's projects in terms of cost? (i.e., are most projects cheap with a few expensive ones, or the other way around?) (1 pt)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 2: Synthesizing Analysis Results (4 points)
#
# This question references the groupby() output showing average cost per building type and the final DataFrame with the Project_Category column.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) Which building type has the highest average cost? (1pt)
#
# b) Which building type shows the greatest variability or inconsistency in its project costs? (1pt) How is this variability represented on the chart? (1pt)
#
# c) The "Industrial" and "Educational" building types have no error bars. What does this signify about the data available for these project types in our dataset? (1pt)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 3: Understanding Conditional Logic (2 points)
#
# For the project categorization, you used an if-elif-else structure.
#
# CORRECT CODE:
# ```
#
# # Part A: Project Categorization
# # Initialize an empty list to store the categories
# project_categories = []
#
# # Use a for loop and if-elif-else statements to categorize each project
# for rating in df['rating']:
#     if pd.isna(rating):
#         project_categories.append('Not Rated')
#     elif rating >= 4.0:
#         project_categories.append('Excellent')
#     elif rating >= 3.0:
#         project_categories.append('Good')
#     elif rating >= 2.0:
#         project_categories.append('Average')
#     else:
#         project_categories.append('Poor')
#
# # Add the list as a new column named Project_Category
# df['Project_Category'] = project_categories
# ```
#
#  A colleague suggests you could have used a series of separate if statements instead, like this:
#
# Python
#
# ```# Colleague's incorrect suggestion:
#
# if rating >= 4.0:
#     category = 'Excellent'
# if rating >= 3.0:
#     category = 'Good'
# if rating >= 2.0:
#     category = 'Average'
# if pd.isna(rating):
#     category = 'Not Rated'
# ```
#
# Explain the specific problem or incorrect result that would occur for a project with a rating of 4.6 if you used this series of separate if statements instead of if-elif-else. (2pts)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 4: Analyzing the Iterative Design Simulation (5 pts)
# Refer to the "Beam Capacity vs. Design Iteration" line plot and the simulation script.
#
# a) The plot shows that the "Moment Capacity" line is a curve, not a straight line. What specific part of the calculation (moment_capacity_lbft = 0.9 * beam_width_ft * (beam_height_ft**2)) causes this curve? (Explain your reasoning. (1pt)
#
# b) The script increases the beam_height_ft by 0.1 ft in each iteration. If you changed this increment to 0.5 ft, how would the final calculated beam_height_ft likely change? (1 pt) Would it be higher, lower, or roughly the same? (1pt) Explain why. (1 pt)
#
# c) In this simulation, what is the role of the while loop? Why is it a more appropriate choice for this problem than a for loop that runs a fixed number of times (e.g., for i in range(50))? (1pt)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb
