# %% [markdown]
# # Part 1: Take-Home Programming (25 Points)
#
# **Instructions**: This is an open-note, open-resource section. Write complete, functional Python scripts to solve the following two tasks.

# %% [markdown]
# ## Task 1: Data Analysis, Visualization, and Filtering (15 points)
#
# You are an analyst at an architectural engineering firm reviewing recent project data. Your goal is to categorize, visualize, and analyze the dataset below.

# %%
# Data provided
data = {
    'project_id': [101, 102, 103, 104, 105, 106, 107],
    'building_type': ['Residential', 'Commercial', 'Educational', 'Residential', 'Industrial', 'Residential', 'Commercial'],
    'location': ['Urban', 'Rural', 'Urban', 'Urban', 'Rural', 'Urban', 'Rural'],
    'size_sqft': [2500, 15000, 8000, 3200, 25000, 4500, 12000],
    'cost_millions': [1.8, 8.5, 4.1, 2.6, 12.0, 3.5, 6.2],
    'duration_months': [12, 24, 18, 14, 30, 16, 20],
    'rating': [1.8, 4.6, 3.2, 2.6, 4.9, 'NA', 3.7]
}

# %% [markdown]
# **Part A: Project Categorization (4 points)**
#
# Initialize the DataFrame above, representing the 'NA' as np.nan. (1pt)
#
# Use a for loop and if-elif-else statements to categorize each project based on its rating using the following criteria:
# - 'Excellent' for ratings >= 4.0
# - 'Good' for ratings >= 3.0 and < 4.0
# - 'Average' for ratings >= 2.0 and < 3.0
# - 'Poor' for ratings < 2.0
# - 'Not Rated' for missing values (np.nan)
# (1pt) Store these categories in a new list. (1pt)
#
# Add this list as a new column named Project_Category. (1pt)

# %%
# your code here

# %% [markdown]
# **Part B: Data Visualization (4 points)**
#
#
# Categorical Bar Chart: Create a bar chart showing the total count of projects for each building_type.  (1pt)
#
#
# Histogram: Create a histogram to visualize the distribution of the cost_millions column.  (1pt)
#
# For both plots, ensure you include a clear title and labels for the x and y axes (1 pt for each)

# %%
# your code here

# %% [markdown]
# **Part C: Grouped Analysis and Visualization (5 points)**
#
# Your team lead wants to understand not only the average cost for different project types but also the variability in cost.
#
# Using the groupby() method, calculate two separate summary statistics for the cost_millions of each building_type:
#
# * The mean cost (1pt)
#
# * The standard deviation of the cost (1pt)
#
# Create a bar chart that visualizes the mean cost for each building type. (1pt)
#
# On the same bar chart, add error bars that represent the standard deviation you calculated for each building type. Use the yerr parameter in your plotting function to achieve this. (1pt)
#
# Ensure your final plot has a clear title and labels for the x and y axes. (1pt)
#
# (Hint: Some building types only appear once, which will result in a NaN for their standard deviation. You may need to handle these NaN values (e.g., by filling them with 0) before plotting the error bars.)

# %%
# your code here

# %% [markdown]
# **Part D: Targeted Analysis with "and" (2 points)**
#
# Filter the DataFrame to find only the projects that meet both of the following criteria:
#
# The building_type is 'Residential'. (1pt)
#
# AND the location is 'Urban'. (1pt)
#
# Print the resulting filtered DataFrame.

# %%
# your code here

# %% [markdown]
# ## Task 2: Iterative Design and Visualization (10 points)
#
# A structural engineer needs to determine the minimum required height for a reinforced concrete beam to safely support a calculated load. You will write a script that simulates this iterative design process and visualizes the result.

# %% [markdown]
# **Part A: Simulation with a while Loop (5 points)**
#
# Your script should perform the entire simulation using feet as the base unit to ensure consistency.
#
# Instructions:
#
# Start with the following initial variables (1pt)
#
# * applied_moment = 60 (in lb-ft)
#
# * beam_width = 3 (in ft)
#
# * beam_height = 1.0 (initial height in ft)
#
# The beam is considered safe when its moment_capacity is greater than the applied_moment.
#
# Use a while loop that continues as long as moment_capacity is less than or equal to applied_moment. (1pt)
#
# Inside the loop:
#
# Calculate the moment_capacity using the formula: moment_capacity = 0.9 * beam_width * (beam_height**2) (1pt)
#
# If the capacity is not yet sufficient, increase the beam_height by 0.1 ft. (1pt)
#
# After the loop terminates, print a message stating the final required beam_height (in feet) that meets the safety requirement. (1pt)

# %%
# your code here

# %% [markdown]
# **Part B: Visualization of the Process (5 points)**
#
# Modify your script from Part A. Before the while loop, initialize an empty list to store the moment_capacity calculated in each iteration. (1pt)
#
# Inside the while loop, after you calculate moment_capacity, append it to your list. (1 pt)
#
# After the loop finishes, create a line plot to visualize the simulation:
#
# * Plot the list of moment_capacity values you collected. This will show the beam's capacity increasing with each iteration. (1pt)
#
# * Add a constant horizontal line representing the applied_moment. This will create a clear visual target for the capacity. (1pt)
#
# Ensure the plot has a title ("Beam Capacity vs. Design Iteration"), a legend, and labels for the x-axis ("Iteration Number") and y-axis ("Moment (lb-ft)") (1pt).

# %%
# your code here

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb
