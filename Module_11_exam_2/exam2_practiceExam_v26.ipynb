# %% [markdown]
# # Part 1: Take-Home Programming (25 Points)
#
# **Instructions**: This is an open-note, open-resource section. Write complete, functional Python scripts to solve the following two tasks.

# %% [markdown]
# ## Task 1: Data Analysis, Visualization, and Filtering (15 points)
#
# You are an analyst at an architectural engineering firm reviewing recent lighting project data. Your goal is to categorize, visualize, and analyze the dataset below.

# %%
# Data
data = {
    'project_id': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'building_type': ['Office', 'Retail', 'Residential', 'Office', 'Industrial', 'Retail', 'Office', 'Residential', 'Hospitality', 'Retail'],
    'fixture_type': ['LED Downlights', 'Track Lighting', 'Pendant Lights', 'Troffers', 'High Bay', 'Linear Fixtures', 'LED Panels', 'Landscape Lighting', 'Decorative Fixtures', 'Spotlights'],
    'area_sqft': [1500, 5000, 2000, 10000, 30000, 6000, 8000, 1500, 12000, 4000],
    'kwh_savings_annual': [2000, 8000, 3000, 15000, 50000, 'NA', 12000, 2500, 18000, 7000],
    'cost': [5000, 25000, 8000, 40000, 150000, 30000, 35000, 7000, 60000, 500000]
}

# %% [markdown]
# **Part A: Project Categorization (4 points)**
#
# Initialize the DataFrame above, representing the 'NA' in the 'rating' column as np.nan. (1pt)
#
# Categorize each project based on its **cost** using the following criteria:
# - 'Low Cost' for costs less than \$10,000
# - 'Medium Cost' for costs between \$10,000 and \$50,000 (inclusive of \$10,000, exclusive of \$50,000)
# - 'High Cost' for costs \$50,000 or greater
#
# Use if-elif-else statements to implement these categories. (1pt) Store these categories in a new list. (1pt)
#
# Add this list as a new column named Project_Cost_Category. (1pt)

# %%
# your code here

# %% [markdown]
# **Part B: Data Visualization (4 points)**
#
# Categorical Bar Chart: Create a bar chart showing the total count of projects for each **Project_Cost_Category**. (1pt)
#
# Histogram: Create a histogram to visualize the distribution of the **cost** column. (1pt)
#
# For both plots, ensure you include a clear title and labels for the x and y axes (1 pt for each)

# %%
# your code here

# %% [markdown]
# **Part C: Grouped Analysis and Visualization (5 points)**
#
# Your team lead wants to understand not only the average cost for different project types but also the variability in cost.
#
# Using the groupby() method, calculate two separate summary statistics for the **cost** of each building_type:
#
# * The mean cost (1pt)
# * The standard deviation of the cost (1pt)
#
# Create a bar chart that visualizes the mean cost for each building type. (1pt)
#
# On the same bar chart, add error bars that represent the standard deviation you calculated for each building type. Use the yerr parameter in your plotting function to achieve this. (1pt)
#
# Ensure your final plot has a clear title and labels for the x and y axes. (1pt)
#
# (Hint: Some building types only appear once, which will result in a NaN for their standard deviation. You may need to handle these NaN values (e.g., by filling them with 0) before plotting the error bars.)

# %%
# your code here

# %% [markdown]
# **Part D: Targeted Analysis with "and" (2 points)**
#
# Filter the DataFrame to find only the projects that meet both of the following criteria:
#
# The building_type is 'Office'. (1pt)
#
# AND the fixture_type is 'LED Downlights'. (1pt)
#
# Print the resulting filtered DataFrame.

# %%
# your code here

# %% [markdown]
# ## Task 2: Iterative Design and Visualization (10 points)
# A mechanical engineer needs to determine the minimum fan speed (in RPM) for an HVAC system to generate enough static pressure to move air through the ductwork. You will write a script that simulates this iterative selection process and visualizes the result.

# %% [markdown]
# **Part A: Simulation with a while Loop (5 points)**
# Instructions:
#
# Start with the following initial variables:
#
# ```
# required_pressure = 150 (in Pascals, Pa)
#
# fan_curve_factor = 0.0002 (a constant specific to this fan)
#
# fan_speed = 500 (initial speed in RPM)
# ```
#
# The system is considered adequate when its generated_pressure is greater than the required_pressure.
#
# Use a while loop that continues as long as generated_pressure is less than or equal to required_pressure.
#
# Inside the loop:
#
# * Calculate the generated_pressure using the formula: generated_pressure = fan_curve_factor * (fan_speed**2).
#
# * If the pressure is not yet sufficient, increase the fan_speed by 50 RPM.
#
# After the loop terminates, print a message stating the final required fan_speed (in RPM) that meets the pressure requirement.

# %%
# your code here

# %% [markdown]
# **Part B: Visualization of the Process (5 points)**
#
# Modify your script from Part A. Before the while loop, initialize two empty lists: one to store the generated_pressure from each iteration, and another to store the corresponding fan_speed.
#
# Inside the while loop, after you calculate generated_pressure, append both the generated_pressure and the current fan_speed to their respective lists.
#
# After the loop finishes, create a line plot to visualize the simulation:
#
# Plot the list of generated_pressure values you collected. This will show the fan's pressure output increasing with each iteration.
#
# Add a constant horizontal line representing the required_pressure. This will create a clear visual target for the pressure.
#
# Ensure the plot has a title ("Fan Pressure vs. Speed Iteration"), a legend, and labels for the x-axis ("Iteration Number") and y-axis ("Pressure (Pa)").

# %%
# your code here

# %% [markdown]
# # Part 2: In-Class Conceptual Analysis (14 Points)
#
# **Instructions**: This is a 30-minute closed-book, closed-note exam. You will be provided with the expected outputs (DataFrames and plots) from the take-home programming portion of the exam. Please answer the following questions based on those outputs and the concepts covered in class.
#
# Here was the raw data you were looking at:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 1: Interpreting Data Distribution (3 points)
#
# Examine the histogram you created for project costs.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) Describe the shape of the distribution (1 pts). Is the data symmetric or is it skewed? If skewed, in which direction (left or right)? (1 pt)
#
# b) What does this shape suggest about the nature of the firm's lighting projects in terms of cost (i.e., are most projects cheap with a few expensive ones, or the other way around)?  (1 pt)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 2: Synthesizing Analysis Results (4 points)
#
# This question references the groupby() output showing average cost per building type and the final DataFrame with the Project_Category column.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) Which building type has the highest average cost? (1pt)
#
# b) Which building type shows the greatest variability or inconsistency in its project costs? (1pt) How is this variability represented on the chart? (1pt)
#
# c) The "Industrial" and "Hospitality" building types have no error bars. What does this signify about the data available for these project types in our dataset? (1pt)
#
# d) The extreme variability for the 'Retail' category is caused by a single outlier. Looking at the raw data, which project (by its project_id) is this outlier? (1pt)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 3: Understanding Conditional Logic (2 points)
#
# For the project categorization, you used an if-elif-else structure.
#
# CORRECT CODE:
# ```
# # Initialize an empty list to store the categories
# project_cost_categories = []
#
# # Categorize each project based on cost
# for cost in df['cost']:
#     if cost < low_threshold:
#         project_cost_categories.append('Low Cost')
#     elif low_threshold <= cost < high_threshold:
#         project_cost_categories.append('Medium Cost')
#     else:
#         project_cost_categories.append('High Cost')
#
# # Add the list as a new column named Project_Cost_Category
# df['Project_Cost_Category'] = project_cost_categories
# ```
#
#  A colleague suggests you could have used a series of separate if statements instead, like this:
#
# Python
#
# ```# Colleague's incorrect suggestion:
#
# # INCORRECT METHOD
# if cost < 10000:
#     category = 'Low Cost'
# if cost < 50000:
#     category = 'Medium Cost'
# if cost >= 50000:
#     category = 'High Cost'
# ```
#
# Explain the specific problem or incorrect result that would occur for a project with a cost of $8,000 if you used this series of separate if statements instead of the correct if-elif-else structure. (2pts)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 4: Analyzing the Iterative Design Simulation (5 pts)
# Refer to the "Fan Pressure vs. Speed Iteration" line plot and the HVAC simulation script from Task 2.
#
# a) The plot shows that the "Generated Pressure" line is a curve, not a straight line. What specific part of the calculation (generated_pressure = fan_curve_factor * (fan_speed**2)) causes this curve? Explain your reasoning.
#
# b) The script increases the fan_speed by 50 RPM in each iteration. If you changed this increment to 300 RPM, how would the final calculated fan_speed likely change? Would it be higher, lower, or roughly the same? Explain why.
#
# c) In this fan simulation, what is the role of the while loop? Why is it a more appropriate choice for this problem than a for loop that runs a fixed number of times (e.g., for i in range(50))?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb
