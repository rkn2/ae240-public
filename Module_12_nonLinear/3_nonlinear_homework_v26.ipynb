# %% [markdown]
# # What I Hope You Learn from This Homework (20 pts)
# In this assignment, you will put your data analysis skills into practice on a real-world engineering problem! The goal is to go beyond just writing code and to start thinking like an engineer!
#
# In this assignment I hope that you:
# * see that there's often more than one way to model a relationship and learn how to implement quadratic, cubic, and exponential models.
#
# * master the use of SciPy's curve_fit to fit custom, non-linear functions to a dataset
#
# * use a key statistical metric, Mean Squared Error (MSE), to objectively determine which model best represents the data
#
# * link your computational results back to the underlying physics of beam deflection, asking the always important question: "Does my model make sense?"
#
#
# ---
#
# **Generative AI Policy:** You are welcome to use AI tools to help you learn, understand, and debug. If you do, you must disclose it. For any task where you used AI, include the tool name, the exact prompt, and a brief description of how you used the output. If you did not use AI on a task, write: *"No AI used."* You will receive the point either way as long as you note it.

# %% [markdown]
# # so here's the problem!
# We have data from an experimental setup:
#
# * Beams: 100 simply supported beams with varying lengths were used for the experiment.
#   * E = 6.8E9 Pa
#   * I = 1.6E-6 m4
#
# * Instrumentation: Displacement sensors were placed at midspan to measure deflection. Accelerometers were also installed to monitor vibration responses.
#
# * Loading: a 400 N load was applied to the 100 beams of varying lengths at midspan.
#
# * Data Acquisition: Data on deflection and vibration were continuously recorded during loading and unloading cycles using data acquisition software.
#
# The objective of this exercise is to analyze synthetic nonlinear beam data representing the deflection (delta) of a beam with respect to its length (L). We will explore various nonlinear models and compare their performance using Mean Squared Error (MSE).

# %% [markdown]
# Import the pandas library and read the provided CSV file, 'nonlinear_beam_data.csv', into a pandas DataFrame named df. (1pt)
#
# Display the first few rows of the DataFrame using the head() method. (1pt)
#
# Plot the scatter plot showing the relationship between the length (L) and the deflection (delta). (1pt)

# %%
# your code here

# %% [markdown]
# Defining the appropriate models for fitting the data is often an iterative process that involves considering the characteristics of the data and the underlying physical or theoretical principles. Here's a thought process to guide the selection of the models:
#
# * Examine the Data: Begin by plotting the data and visually inspecting the relationship between the independent and dependent variables.
# Look for any patterns or trends that may suggest the form of the relationship.
#
# * Consider Theoretical Background: If there's prior knowledge or theoretical understanding of the system that generated the data, it can provide insights into the appropriate functional forms for the models. For example, in beam deflection, theoretical models based on physics principles may guide the selection of appropriate functions.

# %% [markdown]
# Let's consider these different types of curves below. Do any of them look like your data?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# citation = https://go.gale.com/ps/i.do?id=GALE%7CA191214299&sid=googleScholar&v=2.1&it=r&linkaccess=abs&issn=00092460&p=AONE&sw=w&userGroupName=anon%7Ee6f62ec3&aty=open-web-entry

# %% [markdown]
# Based on this chart, let's consider three different nonlinear models:
#
# Quadratic model: $y = ax^2 + bx + c$
#
# Cubic model: $y = ax^3 + bx^2 + cx + d$
#
# Exponential model: $y = ae^{bx} + c$

# %% [markdown]
# Fit each model to the data using curve fitting. (1pt for each of the three models)
#
# Generate predicted values (popt) using the fitted models and print them to the screen. (1pt for each of the three models)
#
# Plot the scatter plot of the data along with the fitted curves for each model. (1pt for each of the three models)
#
# Compute the Mean Squared Error (MSE) for each model. (1pt for each of the three models)
#
#
# Visualize the MSE values in a bar chart, comparing the performance of the three models.(1pt)

# %%
# your code here

# %% [markdown]
# Consider beam deflection tables: https://mechanicalc.com/reference/beam-deflection-tables
#
# Does your response make sense considering what the maximum deflection of a simply supported beam loaded at midspan would be? (1 pt) Explain why or why not. (1 pt)

# %% [markdown]
# # your text here

# %% [markdown]
# ## AI Reflection (2 pts)
#
# In the text cell below, briefly describe your use of any AI tools (ChatGPT, Claude, Copilot, etc.) on this homework.
#
# - What tasks did you use AI for? (1 pt)
# - Did the AI give you correct information? How could you tell? (1 pt)
#
# If you did not use any AI tools, write "None."

# %% [markdown]
# *Write your response here.*

# %% [markdown]
# **Submission:** Please submit 1) the link (make sure that your sharing access is on) and 2) the static .ipynb as a file upload. You will not get any credit if one of those is missing.

# %% [markdown]
# To download the static .ipynb file go to file, download, .ipynb
